# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### import and clean

# %%
data_init = pd.read_csv("train-data/fight_data.csv")

# %%
data_init.head()
# Out:
#                     Date        fighter1 fighter1_result method_or_round  \
# 0   Saturday, 3 May 2025  Canelo Alvarez          Winner    UD, Round 12
# 1   Saturday, 3 May 2025   Jukiya Iimura          Winner    UD, Round 12
# 2     Friday, 2 May 2025     Ryan Garcia           Loser    UD, Round 12
# 3   Thursday, 1 May 2025    Kevin Lerena          Winner    TKO, Round 3
# 4  Sunday, 27 April 2025  Marlon Tapales          Winner    RTD, Round 3
#
#                  fighter2                                              Venue  \
# 0           William Scull                    The Venue, Riyadh, Saudi Arabia
# 1          Esneth Domingo                        Korakuen Hall, Tokyo, Japan
# 2  Rolando ‘Rolly’ Romero          Times Square, New York, NY, United States
# 3        Serhiy Radchenko               Sunbet Arena, Pretoria, South Africa
# 4             Jon Jon Jet  General Santos City, Cotabato del Sur, Philipp...
#
#                                     Undercard fights  \
# 0  Jaime Munguia Beat  Bruno Surace (UD 12) \nMar...
# 1                                                NaN
# 2  Devin Haney Beat  Jose Ramirez (UD 12) \nTeofi...
# 3                                                NaN
# 4                                                NaN
#
#                                            link  fighter1_record_wins  \
# 0      https://box.live/fights/canelo-vs-scull/                    62
# 1    https://box.live/fights/iimura-vs-domingo/                     8
# 2     https://box.live/fights/garcia-vs-romero/                    24
# 3  https://box.live/fights/lerena-vs-radchenko/                    30
# 4       https://box.live/fights/tapales-vs-jet/                    39
#
#    fighter1_record_draws  fighter1_record_losses  fighter2_record_wins  \
# 0                      2                       2                    23
# 1                      1                       0                    21
# 2                      1                       0                    16
# 3                      3                       0                    11
# 4                      4                       0                    15
#
#    fighter2_record_draws  fighter2_record_losses  fighter1_height_cm  \
# 0                      0                       0                 175
# 1                      2                       0                 164
# 2                      2                       0                 178
# 3                      7                       0                 185
# 4                      1                       1                 163
#
#    fighter2_height_cm  fighter1_ko_percentage  fighter2_ko_percentage
# 0               182.0                       0                       0
# 1               160.0                       0                       0
# 2               173.0                      83                      81
# 3               186.0                      47                      45
# 4               166.0                       0                       0

# %%
df_essentials = data_init.drop(columns=['link','Venue','Date','Undercard fights','fighter1','fighter2'])
df_essentials.head(2)
# Out:
#   fighter1_result method_or_round  fighter1_record_wins  \
# 0          Winner    UD, Round 12                    62
# 1          Winner    UD, Round 12                     8
#
#    fighter1_record_draws  fighter1_record_losses  fighter2_record_wins  \
# 0                      2                       2                    23
# 1                      1                       0                    21
#
#    fighter2_record_draws  fighter2_record_losses  fighter1_height_cm  \
# 0                      0                       0                 175
# 1                      2                       0                 164
#
#    fighter2_height_cm  fighter1_ko_percentage  fighter2_ko_percentage
# 0               182.0                       0                       0
# 1               160.0                       0                       0

# %%
df_staged_cleaning = df_essentials.copy()
df_staged_cleaning.head(2)
# Out:
#   fighter1_result method_or_round  fighter1_record_wins  \
# 0          Winner    UD, Round 12                    62
# 1          Winner    UD, Round 12                     8
#
#    fighter1_record_draws  fighter1_record_losses  fighter2_record_wins  \
# 0                      2                       2                    23
# 1                      1                       0                    21
#
#    fighter2_record_draws  fighter2_record_losses  fighter1_height_cm  \
# 0                      0                       0                 175
# 1                      2                       0                 164
#
#    fighter2_height_cm  fighter1_ko_percentage  fighter2_ko_percentage
# 0               182.0                       0                       0
# 1               160.0                       0                       0

# %%
df_staged_cleaning['method_or_round'] = df_staged_cleaning['method_or_round'].str.split(' ')

# %%
last_rounds = [new_list[2] for new_list in df_staged_cleaning['method_or_round']][:]
df_staged_cleaning['round'] = last_rounds

df_staged_cleaning.head()
# Out:
#   fighter1_result   method_or_round  fighter1_record_wins  \
# 0          Winner  [UD,, Round, 12]                    62
# 1          Winner  [UD,, Round, 12]                     8
# 2           Loser  [UD,, Round, 12]                    24
# 3          Winner  [TKO,, Round, 3]                    30
# 4          Winner  [RTD,, Round, 3]                    39
#
#    fighter1_record_draws  fighter1_record_losses  fighter2_record_wins  \
# 0                      2                       2                    23
# 1                      1                       0                    21
# 2                      1                       0                    16
# 3                      3                       0                    11
# 4                      4                       0                    15
#
#    fighter2_record_draws  fighter2_record_losses  fighter1_height_cm  \
# 0                      0                       0                 175
# 1                      2                       0                 164
# 2                      2                       0                 178
# 3                      7                       0                 185
# 4                      1                       1                 163
#
#    fighter2_height_cm  fighter1_ko_percentage  fighter2_ko_percentage round
# 0               182.0                       0                       0    12
# 1               160.0                       0                       0    12
# 2               173.0                      83                      81    12
# 3               186.0                      47                      45     3
# 4               166.0                       0                       0     3

# %%
df_staged_cleaning = df_staged_cleaning.drop(columns='method_or_round')
df_staged_cleaning.head()
# Out:
#   fighter1_result  fighter1_record_wins  fighter1_record_draws  \
# 0          Winner                    62                      2
# 1          Winner                     8                      1
# 2           Loser                    24                      1
# 3          Winner                    30                      3
# 4          Winner                    39                      4
#
#    fighter1_record_losses  fighter2_record_wins  fighter2_record_draws  \
# 0                       2                    23                      0
# 1                       0                    21                      2
# 2                       0                    16                      2
# 3                       0                    11                      7
# 4                       0                    15                      1
#
#    fighter2_record_losses  fighter1_height_cm  fighter2_height_cm  \
# 0                       0                 175               182.0
# 1                       0                 164               160.0
# 2                       0                 178               173.0
# 3                       0                 185               186.0
# 4                       1                 163               166.0
#
#    fighter1_ko_percentage  fighter2_ko_percentage round
# 0                       0                       0    12
# 1                       0                       0    12
# 2                      83                      81    12
# 3                      47                      45     3
# 4                       0                       0     3

# %% [markdown]
# ### copy over data frame and swap values

# %%
df_staged_swapping = df_staged_cleaning.copy()

# %%
fighter2_wins_temp = df_staged_swapping['fighter2_record_wins'].copy()
fighter2_draws_temp = df_staged_swapping['fighter2_record_draws'].copy()
fighter2_losses_temp = df_staged_swapping['fighter2_record_losses'].copy()
fighter2_height_cm_temp = df_staged_swapping['fighter2_height_cm'].copy()
fighter2_ko_percentage_temp = df_staged_swapping['fighter2_ko_percentage'].copy()

# %%
df_staged_swapping['fighter2_record_wins'] = df_staged_swapping['fighter1_record_wins']
df_staged_swapping['fighter2_record_draws'] = df_staged_swapping['fighter1_record_draws']
df_staged_swapping['fighter2_record_losses'] = df_staged_swapping['fighter1_record_losses']
df_staged_swapping['fighter2_height_cm'] = df_staged_swapping['fighter1_height_cm']
df_staged_swapping['fighter2_ko_percentage'] = df_staged_swapping['fighter1_ko_percentage']

# %%
df_staged_swapping['fighter1_record_wins'] = fighter2_wins_temp
df_staged_swapping['fighter1_record_draws'] = fighter2_draws_temp
df_staged_swapping['fighter1_record_losses'] = fighter2_losses_temp
df_staged_swapping['fighter1_height_cm'] = fighter2_height_cm_temp
df_staged_swapping['fighter1_ko_percentage'] = fighter2_ko_percentage_temp

# %%
def reverse_results(rowval) : 
    if rowval == 'Winner' :
        return 'Loser'
    elif rowval == 'Loser' :
        return 'Winner'
    else :
        return 'Draw'

# %%
df_staged_swapping['fighter1_result'] = df_staged_swapping['fighter1_result'].apply(reverse_results)

# %%
# entire function to swap values
def swap_fighters() :
    df_staged_swapping = df_staged_cleaning.copy()
    
    fighter2_wins_temp = df_staged_swapping['fighter2_record_wins'].copy()
    fighter2_draws_temp = df_staged_swapping['fighter2_record_draws'].copy()
    fighter2_losses_temp = df_staged_swapping['fighter2_record_losses'].copy()
    fighter2_height_cm_temp = df_staged_swapping['fighter2_height_cm'].copy()
    fighter2_ko_percentage_temp = df_staged_swapping['fighter2_ko_percentage'].copy()

    df_staged_swapping['fighter2_record_wins'] = df_staged_swapping['fighter1_record_wins']
    df_staged_swapping['fighter2_record_draws'] = df_staged_swapping['fighter1_record_draws']
    df_staged_swapping['fighter2_record_losses'] = df_staged_swapping['fighter1_record_losses']
    df_staged_swapping['fighter2_height_cm'] = df_staged_swapping['fighter1_height_cm']
    df_staged_swapping['fighter2_ko_percentage'] = df_staged_swapping['fighter1_ko_percentage']

    df_staged_swapping['fighter1_record_wins'] = fighter2_wins_temp
    df_staged_swapping['fighter1_record_draws'] = fighter2_draws_temp
    df_staged_swapping['fighter1_record_losses'] = fighter2_losses_temp
    df_staged_swapping['fighter1_height_cm'] = fighter2_height_cm_temp
    df_staged_swapping['fighter1_ko_percentage'] = fighter2_ko_percentage_temp

    def reverse_results(rowval) : 
        if rowval == 'Winner' :
            return 'Loser'
        elif rowval == 'Loser' :
            return 'Winner'
        else :
            return 'Draw'
        
    df_staged_swapping['fighter1_result'] = df_staged_swapping['fighter1_result'].apply(reverse_results)

# %%
df_staged_cleaning
# Out:
#    fighter1_result  fighter1_record_wins  fighter1_record_draws  \
# 0           Winner                    62                      2
# 1           Winner                     8                      1
# 2            Loser                    24                      1
# 3           Winner                    30                      3
# 4           Winner                    39                      4
# 5           Winner                    34                      3
# 6           Winner                     8                      0
# 7           Winner                    17                      0
# 8           Winner                    15                      0
# 9             Draw                    15                      0
# 10          Winner                    35                      5
# 11          Winner                     6                      0
#
#     fighter1_record_losses  fighter2_record_wins  fighter2_record_draws  \
# 0                        2                    23                      0
# 1                        0                    21                      2
# 2                        0                    16                      2
# 3                        0                    11                      7
# 4                        0                    15                      1
# 5                        0                    23                      0
# 6                        1                    23                      6
# 7                        0                    26                      2
# 8                        0                    19                      0
# 9                        0                    23                      6
# 10                       1                    22                      4
# 11                       0                    14                      2
#
#     fighter2_record_losses  fighter1_height_cm  fighter2_height_cm  \
# 0                        0                 175               182.0
# 1                        0                 164               160.0
# 2                        0                 178               173.0
# 3                        0                 185               186.0
# 4                        1                 163               166.0
# 5                        0                 180               173.0
# 6                        1                 191               183.0
# 7                        1                 176                 NaN
# 8                        1                 175               160.0
# 9                        0                 175               178.0
# 10                       0                 183               185.0
# 11                       0                 175               175.0
#
#     fighter1_ko_percentage  fighter2_ko_percentage round
# 0                        0                       0    12
# 1                        0                       0    12
# 2                       83                      81    12
# 3                       47                      45     3
# 4                        0                       0     3
# 5                       74                      61    12
# 6                       63                      43     2
# 7                        0                       0    12
# 8                        0                       0     7
# 9                        0                       0    10
# 10                      83                      59     7
# 11                       0                       0    10

# %%
df_staged_swapping
# Out:
#    fighter1_result  fighter1_record_wins  fighter1_record_draws  \
# 0            Loser                    23                      0
# 1            Loser                    21                      2
# 2           Winner                    16                      2
# 3            Loser                    11                      7
# 4            Loser                    15                      1
# 5            Loser                    23                      0
# 6            Loser                    23                      6
# 7            Loser                    26                      2
# 8            Loser                    19                      0
# 9             Draw                    23                      6
# 10           Loser                    22                      4
# 11           Loser                    14                      2
#
#     fighter1_record_losses  fighter2_record_wins  fighter2_record_draws  \
# 0                        0                    62                      2
# 1                        0                     8                      1
# 2                        0                    24                      1
# 3                        0                    30                      3
# 4                        1                    39                      4
# 5                        0                    34                      3
# 6                        1                     8                      0
# 7                        1                    17                      0
# 8                        1                    15                      0
# 9                        0                    15                      0
# 10                       0                    35                      5
# 11                       0                     6                      0
#
#     fighter2_record_losses  fighter1_height_cm  fighter2_height_cm  \
# 0                        2               182.0                 175
# 1                        0               160.0                 164
# 2                        0               173.0                 178
# 3                        0               186.0                 185
# 4                        0               166.0                 163
# 5                        0               173.0                 180
# 6                        1               183.0                 191
# 7                        0                 NaN                 176
# 8                        0               160.0                 175
# 9                        0               178.0                 175
# 10                       1               185.0                 183
# 11                       0               175.0                 175
#
#     fighter1_ko_percentage  fighter2_ko_percentage round
# 0                        0                       0    12
# 1                        0                       0    12
# 2                       81                      83    12
# 3                       45                      47     3
# 4                        0                       0     3
# 5                       61                      74    12
# 6                       43                      63     2
# 7                        0                       0    12
# 8                        0                       0     7
# 9                        0                       0    10
# 10                      59                      83     7
# 11                       0                       0    10
